# %% [markdown]
# # Identifying instances of co-location in synthetic mobility trajectories

# %% [markdown]
# ## Imports

# %%
import skmob
import geopandas as gpd
import pandas as pd
import numpy as np
from itertools import combinations

# %% [markdown]
# ## Functions

# %%
def is_spatially_proximal(lat1: float, lat2: float, lng1: float, lng2: float) -> bool:
    return ((lat1==lat2) & (lng1==lng2))

# %%
def is_temporally_proximal(t1: np.datetime64, t2: np.datetime64) -> bool:
    condition = (t1 - np.timedelta64(4, "h") <= t2) & (t2 <= t1 + np.timedelta64(4, "h"))
    return condition

# %% [markdown]
# ## Read data

# %%
tdf = skmob.TrajDataFrame.from_file("data/traj.csv")

# %%
tdf.plot_trajectory()
# Out:
# /home/keiran/miniconda3/envs/coloc/lib/python3.12/site-packages/skmob/core/trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# /home/keiran/miniconda3/envs/coloc/lib/python3.12/site-packages/skmob/core/trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56f88e480c57cda67f7b5512c7bd20b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56f88e480c57cda67f7b5512c7bd20b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56f88e480c57cda67f7b5512c7bd20b5 = L.map(
#                 &quot;map_56f88e480c57cda67f7b5512c7bd20b5&quot;,
#                 {
#                     center: [53.75571183775146, -1.605922399159324],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_56f88e480c57cda67f7b5512c7bd20b5);
#
#
#
#
#
#             var tile_layer_32e2705f7f1ebd08f36be81cc44b2703 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_32e2705f7f1ebd08f36be81cc44b2703.addTo(map_56f88e480c57cda67f7b5512c7bd20b5);
#
#
#         function geo_json_f0aac1cad3f5e3ea5195a36abc4556e0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#9400E6&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.75, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_f0aac1cad3f5e3ea5195a36abc4556e0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f0aac1cad3f5e3ea5195a36abc4556e0 = L.geoJson(null, {
#                 onEachFeature: geo_json_f0aac1cad3f5e3ea5195a36abc4556e0_onEachFeature,
#
#                 style: geo_json_f0aac1cad3f5e3ea5195a36abc4556e0_styler,
#         });
#
#         function geo_json_f0aac1cad3f5e3ea5195a36abc4556e0_add (data) {
#             geo_json_f0aac1cad3f5e3ea5195a36abc4556e0
#                 .addData(data);
#         }
#             geo_json_f0aac1cad3f5e3ea5195a36abc4556e0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-1.612396, 53.729001], [-1.620111, 53.734795], [-1.612396, 53.729001], [-1.649769, 53.750034], [-1.606354, 53.73938], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.605922, 53.750792], [-1.603006, 53.748723], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.514945, 53.811053], [-1.612396, 53.729001], [-1.629474, 53.763097], [-1.561998, 53.804578], [-1.562431, 53.873342], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.60001, 53.758172], [-1.634708, 53.775942], [-1.604692, 53.755712], [-1.606354, 53.73938], [-1.624495, 53.741035], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.629474, 53.763097], [-1.604692, 53.755712], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.624495, 53.741035], [-1.634708, 53.775942], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.561998, 53.804578], [-1.559009, 53.808094], [-1.604692, 53.755712], [-1.587004, 53.802035], [-1.561998, 53.804578], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.632437, 53.803763], [-1.622769, 53.799051], [-1.604692, 53.755712], [-1.612235, 53.751517], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.606354, 53.73938], [-1.605922, 53.750792], [-1.604692, 53.755712], [-1.603006, 53.748723], [-1.550645, 53.823542], [-1.632437, 53.803763], [-1.622786, 53.809499], [-1.612396, 53.729001], [-1.559009, 53.808094], [-1.612396, 53.729001], [-1.550645, 53.823542], [-1.629474, 53.763097], [-1.612396, 53.729001], [-1.612235, 53.751517], [-1.612396, 53.729001], [-1.561998, 53.804578], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.632437, 53.803763], [-1.624495, 53.741035], [-1.60001, 53.758172], [-1.56117, 53.752028], [-1.586036, 53.743838], [-1.624495, 53.741035], [-1.561998, 53.804578], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.562431, 53.873342], [-1.604692, 53.755712], [-1.624495, 53.741035], [-1.632437, 53.803763], [-1.604692, 53.755712], [-1.559009, 53.808094], [-1.561998, 53.804578], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.559009, 53.808094], [-1.620111, 53.734795], [-1.612396, 53.729001], [-1.587004, 53.802035], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.562431, 53.873342], [-1.622786, 53.809499], [-1.559009, 53.808094], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.60001, 53.758172], [-1.629474, 53.763097], [-1.615683, 53.758898], [-1.605922, 53.750792], [-1.585913, 53.738466], [-1.617232, 53.806317], [-1.605922, 53.750792], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.624495, 53.741035], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.550645, 53.823542], [-1.629474, 53.763097], [-1.605922, 53.750792], [-1.603006, 53.748723], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.634708, 53.775942]

# %% [markdown]
# ## Create subset

# %% [markdown]
# Create a subset of the data containing only the first 5 individuals to make things a bit easier to visualise and work with.

# %%
stdf = tdf.loc[tdf["uid"]<=5, :]

# %%
stdf.plot_trajectory()
# Out:
# /home/keiran/miniconda3/envs/coloc/lib/python3.12/site-packages/skmob/core/trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# /home/keiran/miniconda3/envs/coloc/lib/python3.12/site-packages/skmob/core/trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72d2999d38fbcd357579e9cad99e2a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72d2999d38fbcd357579e9cad99e2a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72d2999d38fbcd357579e9cad99e2a2 = L.map(
#                 &quot;map_b72d2999d38fbcd357579e9cad99e2a2&quot;,
#                 {
#                     center: [53.75571183775146, -1.605922399159324],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b72d2999d38fbcd357579e9cad99e2a2);
#
#
#
#
#
#             var tile_layer_c9b4f166d02f8c179032104d277051e9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c9b4f166d02f8c179032104d277051e9.addTo(map_b72d2999d38fbcd357579e9cad99e2a2);
#
#
#         function geo_json_dc25a0358244f9ee2cb3850c67787bbf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#003C86&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.75, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_dc25a0358244f9ee2cb3850c67787bbf_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_dc25a0358244f9ee2cb3850c67787bbf = L.geoJson(null, {
#                 onEachFeature: geo_json_dc25a0358244f9ee2cb3850c67787bbf_onEachFeature,
#
#                 style: geo_json_dc25a0358244f9ee2cb3850c67787bbf_styler,
#         });
#
#         function geo_json_dc25a0358244f9ee2cb3850c67787bbf_add (data) {
#             geo_json_dc25a0358244f9ee2cb3850c67787bbf
#                 .addData(data);
#         }
#             geo_json_dc25a0358244f9ee2cb3850c67787bbf_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-1.612396, 53.729001], [-1.620111, 53.734795], [-1.612396, 53.729001], [-1.649769, 53.750034], [-1.606354, 53.73938], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.605922, 53.750792], [-1.603006, 53.748723], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.514945, 53.811053], [-1.612396, 53.729001], [-1.629474, 53.763097], [-1.561998, 53.804578], [-1.562431, 53.873342], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.60001, 53.758172], [-1.634708, 53.775942], [-1.604692, 53.755712], [-1.606354, 53.73938], [-1.624495, 53.741035], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.629474, 53.763097], [-1.604692, 53.755712], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.624495, 53.741035], [-1.634708, 53.775942], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.561998, 53.804578], [-1.559009, 53.808094], [-1.604692, 53.755712], [-1.587004, 53.802035], [-1.561998, 53.804578], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.632437, 53.803763], [-1.622769, 53.799051], [-1.604692, 53.755712], [-1.612235, 53.751517], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.606354, 53.73938], [-1.605922, 53.750792], [-1.604692, 53.755712], [-1.603006, 53.748723], [-1.550645, 53.823542], [-1.632437, 53.803763], [-1.622786, 53.809499], [-1.612396, 53.729001], [-1.559009, 53.808094], [-1.612396, 53.729001], [-1.550645, 53.823542], [-1.629474, 53.763097], [-1.612396, 53.729001], [-1.612235, 53.751517], [-1.612396, 53.729001], [-1.561998, 53.804578], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.632437, 53.803763], [-1.624495, 53.741035], [-1.60001, 53.758172], [-1.56117, 53.752028], [-1.586036, 53.743838], [-1.624495, 53.741035], [-1.561998, 53.804578], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.562431, 53.873342], [-1.604692, 53.755712], [-1.624495, 53.741035], [-1.632437, 53.803763], [-1.604692, 53.755712], [-1.559009, 53.808094], [-1.561998, 53.804578], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.559009, 53.808094], [-1.620111, 53.734795], [-1.612396, 53.729001], [-1.587004, 53.802035], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.562431, 53.873342], [-1.622786, 53.809499], [-1.559009, 53.808094], [-1.624495, 53.741035], [-1.604692, 53.755712], [-1.60001, 53.758172], [-1.629474, 53.763097], [-1.615683, 53.758898], [-1.605922, 53.750792], [-1.585913, 53.738466], [-1.617232, 53.806317], [-1.605922, 53.750792], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.624495, 53.741035], [-1.612396, 53.729001], [-1.604692, 53.755712], [-1.550645, 53.823542], [-1.629474, 53.763097], [-1.605922, 53.750792], [-1.603006, 53.748723], [-1.604692, 53.755712], [-1.612396, 53.729001], [-1.605922, 53.750792], [-1.612396, 53.729001], [-1.634708, 53.775942]

# %% [markdown]
# ## Iterating over individuals

# %%
individuals = stdf["uid"].unique()

# %%
combos = combinations(individuals, 2)

# %%
all_observation_combinations = []

# %%
for combo in combos:
    person1 = stdf.loc[stdf["uid"] == combo[0]]
    person2 = stdf.loc[stdf["uid"] == combo[1]]
    cross = person1.merge(person2, how="cross")
    cross["is_coloc"] = np.where(is_spatially_proximal(
        cross["lat_x"], cross["lat_y"], cross["lng_x"], cross["lng_y"]
    ) & is_temporally_proximal(
        cross["datetime_x"], cross["datetime_y"]
    ), 1, 0)
    all_observation_combinations.append(cross)

# %%
all_observation_combinations = pd.concat(all_observation_combinations)

# %%
all_observation_combinations.head()
# Out:
#    uid_x          datetime_x      lat_x     lng_x  uid_y          datetime_y  \
# 0      1 2024-01-01 08:00:00  53.729001 -1.612396      2 2024-01-01 08:00:00
# 1      1 2024-01-01 08:00:00  53.729001 -1.612396      2 2024-01-01 08:20:15
# 2      1 2024-01-01 08:00:00  53.729001 -1.612396      2 2024-01-01 10:44:20
# 3      1 2024-01-01 08:00:00  53.729001 -1.612396      2 2024-01-01 18:51:07
# 4      1 2024-01-01 08:00:00  53.729001 -1.612396      2 2024-01-01 19:18:01
#
#        lat_y     lng_y  is_coloc
# 0  53.812933 -1.500682         0
# 1  53.812787 -1.488527         0
# 2  53.825503 -1.516227         0
# 3  53.814158 -1.511499         0
# 4  53.815489 -1.508310         0

# %%
sum(all_observation_combinations["is_coloc"])
# Out:
# 22

# %%
hit_rate = (sum(all_observation_combinations["is_coloc"]) / len(all_observation_combinations))

# %%
hit_rate * 100
# Out:
# 0.0052257773343784885

# %%
stdf.loc[stdf["uid"]==1]
# Out:
#      uid            datetime        lat       lng
# 0      1 2024-01-01 08:00:00  53.729001 -1.612396
# 1      1 2024-01-01 08:33:04  53.734795 -1.620111
# 2      1 2024-01-01 09:42:28  53.729001 -1.612396
# 3      1 2024-01-01 10:15:42  53.741035 -1.624495
# 4      1 2024-01-01 10:44:34  53.739380 -1.606354
# ..   ...                 ...        ...       ...
# 223    1 2024-01-14 05:02:04  53.802035 -1.587004
# 224    1 2024-01-14 05:23:40  53.734795 -1.620111
# 225    1 2024-01-14 05:44:23  53.802035 -1.587004
# 226    1 2024-01-14 06:20:38  53.809499 -1.622786
# 227    1 2024-01-14 06:46:16  53.808094 -1.559009
#
# [228 rows x 4 columns]

# %%
from skmob.measures.individual import waiting_times

# %%
wt_df = waiting_times(stdf)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 110.85it/s]

# %%
wt_df
# Out:
#    uid                                      waiting_times
# 0    1  [1984.0, 4164.0, 1994.0, 1732.0, 2266.0, 1812....
# 1    2  [1215.0, 8645.0, 29207.0, 1614.0, 2351.0, 1872...
# 2    3  [1470.0, 1945.0, 2300.0, 1590.0, 1336.0, 4660....
# 3    4  [1922.0, 3808.0, 2700.0, 1244.0, 2656.0, 5521....
# 4    5  [2702.0, 2986.0, 7094.0, 14587.0, 4585.0, 1637...

# %%
wt = wt_df.loc[wt_df["uid"]==1, ["waiting_times"]]

# %%
np.ravel(wt)
# Out:
# array([array([ 1984.,  4164.,  1994.,  1732.,  2266.,  1812., 17751.,  1315.,
#                1669.,  1674.,  1680.,  2998.,  1375.,  5495.,  1829.,  2359.,
#                4993., 12734.,  6083.,  1833.,  1447.,  2911.,  6102.,  3812.,
#                5287.,  4086.,  1294.,  1401.,  1315., 11836.,  3606.,  7394.,
#               13885.,  3128.,  4324.,  1581.,  9235.,  1343.,  2440.,  7384.,
#                1760.,  3319.,  9169.,  2082.,  2172.,  5653.,  2544.,  1482.,
#               12464.,  1731.,  5875.,  6338.,  1604.,  1412.,  1239.,  1465.,
#                1538.,  9967.,  1276.,  1791.,  1495.,  2199., 13678.,  1354.,
#                1386., 11145.,  1625.,  2615.,  5688.,  3611.,  1753.,  1806.,
#               26244.,  5403.,  1524.,  1892.,  5482.,  2274.,  1376.,  2577.,
#               12885.,  2373.,  4666.,  1548.,  1558.,  2945.,  2516., 10169.,
#                1514.,  2452.,  1429.,  4363.,  7501.,  1704.,  7631.,  3650.,
#               44470.,  1973.,  3545.,  1507., 12477.,  1986.,  1386.,  1678.,
#                2125.,  1229.,  8419.,  9506.,  1709., 27506.,  3868.,  1274.,
#                1423.,  2049.,  2001.,  1260.,  2817.,  2453.,  3558.,  2342.,
#                2816.,  1793.,  1341.,  4045.,  3597.,  1617.,  4933.,  2635.,
#                1843.,  2186.,  5434.,  1397.,  1218.,  1277.,  1631., 12132.,
#                2754.,  1793., 41933.,  1925.,  1294.,  9716.,  1689.,  1273.,
#                2773.,  8584., 10195.,  6665.,  6831.,  1749.,  1795.,  1939.,
#                1512.,  1934.,  5501.,  1336.,  3548.,  5513.,  5094.,  1702.,
#                1296., 12371.,  2027.,  1495.,  5163.,  4066.,  1872.,  3397.,
#                4640.,  1984.,  8353., 45004.,  1846., 11049.,  1634.,  7895.,
#                2810., 18198.,  1581.,  1491.,  1473.,  1206.,  1276., 12410.,
#               15567.,  7643., 23531.,  1939.,  3126.,  1609.,  8744., 62918.,
#                2503.,  3470.,  8230.,  6857.,  2487.,  1733.,  1339.,  1400.,
#                1779.,  1545.,  1425.,  3469.,  8575.,  3817.,  1639.,  3438.,
#                1839.,  1714.,  2742.,  1893.,  1697.,  2944.,  1953.,  6362.,
#                6167.,  3816.,  1535.,  1838.,  6004.,  1900.,  4833.,  1296.,
#                1243.,  2175.,  1538.])                                       ],
#       dtype=object)

# %%
for individual in individuals:
    df = stdf.loc[stdf["uid"]==individual, :]
    print(df.shape)
# Out:
# (228, 4)
# (200, 4)
# (206, 4)
# (173, 4)
# (220, 4)

# %%
# Out:
# [(np.int64(1), np.int64(2)),
#  (np.int64(1), np.int64(3)),
#  (np.int64(1), np.int64(4)),
#  (np.int64(1), np.int64(5)),
#  (np.int64(2), np.int64(3)),
#  (np.int64(2), np.int64(4)),
#  (np.int64(2), np.int64(5)),
#  (np.int64(3), np.int64(4)),
#  (np.int64(3), np.int64(5)),
#  (np.int64(4), np.int64(5))]

# %%
user_x = get_user_list_of_dicts(users, "x")
user_y = get_user_list_of_dicts(users, "y")

scol_points = []

for x_record in user_x:
    for y_record in user_y:
        d1 = x_record.copy()
        d2 = y_record.copy()
        
        x_coords = (x_record["x"], x_record["y"])
        y_coords = (y_record["x"], y_record["y"])
        x_time = x_record["time"]
        y_time = y_record["time"]

        condition1 = trace_x_delta(x_coords, y_coords, x_tolerance)
        condition2 = t_delta(x_time, y_time, t_tolerance)

        if condition1 and condition2:
            scol_points.extend([d1, d2])

scol_points = pd.DataFrame(scol_points)
return scol_points

# %%
person1 = stdf.loc[stdf["uid"]==1, :]

# %%
person2 = stdf.loc[stdf["uid"]==2, :]

# %%
combo = person1.merge(person2, how="cross")

# %%
combo
# Out:
#        uid_x          datetime_x      lat_x     lng_x  uid_y  \
# 0          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 1          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 2          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 3          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 4          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# ...      ...                 ...        ...       ...    ...
# 45595      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45596      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45597      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45598      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45599      1 2024-01-14 06:46:16  53.808094 -1.559009      2
#
#                datetime_y      lat_y     lng_y
# 0     2024-01-01 08:00:00  53.812933 -1.500682
# 1     2024-01-01 08:20:15  53.812787 -1.488527
# 2     2024-01-01 10:44:20  53.789568 -1.511633
# 3     2024-01-01 18:51:07  53.748723 -1.603006
# 4     2024-01-01 19:18:01  53.750792 -1.605922
# ...                   ...        ...       ...
# 45595 2024-01-14 01:37:48  53.789568 -1.511633
# 45596 2024-01-14 02:15:38  53.804982 -1.508025
# 45597 2024-01-14 02:37:26  53.789054 -1.548701
# 45598 2024-01-14 03:16:54  53.787941 -1.553949
# 45599 2024-01-14 03:53:51  53.809132 -1.511477
#
# [45600 rows x 8 columns]

# %%
combo["is_coloc"] = np.where(is_colocated(combo["lat_x"], combo["lat_y"], combo["lng_x"], combo["lng_y"]), 1, 0)

# %%
combo
# Out:
#        uid_x          datetime_x      lat_x     lng_x  uid_y  \
# 0          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 1          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 2          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 3          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# 4          1 2024-01-01 08:00:00  53.729001 -1.612396      2
# ...      ...                 ...        ...       ...    ...
# 45595      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45596      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45597      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45598      1 2024-01-14 06:46:16  53.808094 -1.559009      2
# 45599      1 2024-01-14 06:46:16  53.808094 -1.559009      2
#
#                datetime_y      lat_y     lng_y  is_coloc
# 0     2024-01-01 08:00:00  53.812933 -1.500682         0
# 1     2024-01-01 08:20:15  53.812787 -1.488527         0
# 2     2024-01-01 10:44:20  53.789568 -1.511633         0
# 3     2024-01-01 18:51:07  53.748723 -1.603006         0
# 4     2024-01-01 19:18:01  53.750792 -1.605922         0
# ...                   ...        ...       ...       ...
# 45595 2024-01-14 01:37:48  53.789568 -1.511633         0
# 45596 2024-01-14 02:15:38  53.804982 -1.508025         0
# 45597 2024-01-14 02:37:26  53.789054 -1.548701         0
# 45598 2024-01-14 03:16:54  53.787941 -1.553949         0
# 45599 2024-01-14 03:53:51  53.809132 -1.511477         0
#
# [45600 rows x 9 columns]

# %%
sum(combo["is_coloc"])
# Out:
# 73
